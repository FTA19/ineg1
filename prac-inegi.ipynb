# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
df = pd.read_csv("Data-Science/Class/Datos/Proyecciones/basepryentMX.csv")

# %%
ls
# Out:
# Complexity Science/                         Data Mining/   Game theory/
# Complexity Science and Nonlinear Dynamics/  Data-Science/

# %%
df.head(100)
# Out:
#     renglon   año       ent  id_ent  cvegeo     sexo  edad        pob
# 0         1  1990  Nacional       0       0  Hombres     0  1183205.0
# 1         2  1990  Nacional       0       0  Hombres     1  1156333.0
# 2         3  1990  Nacional       0       0  Hombres     2  1136216.0
# 3         4  1990  Nacional       0       0  Hombres     3  1120768.0
# 4         5  1990  Nacional       0       0  Hombres     4  1109014.0
# 5         6  1990  Nacional       0       0  Hombres     5  1100313.0
# 6         7  1990  Nacional       0       0  Hombres     6  1093527.0
# 7         8  1990  Nacional       0       0  Hombres     7  1089446.0
# 8         9  1990  Nacional       0       0  Hombres     8  1088081.0
# 9        10  1990  Nacional       0       0  Hombres     9  1088447.0
# 10       11  1990  Nacional       0       0  Hombres    10  1089182.0
# 11       12  1990  Nacional       0       0  Hombres    11  1088690.0
# ...
